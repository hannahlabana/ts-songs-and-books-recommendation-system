# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# %matplotlib inline
import ipywidgets
import csv
import json

# %% [markdown]
# ---
# ### Books Dataset

# %%
data =[]
with open('booksummaries.txt','r', encoding='utf-8') as f:
    reader = csv.reader(f, dialect='excel-tab')
    for row in reader:
        data.append(row)

books = pd.DataFrame.from_records(data, columns=['book_id', 'freebase_id', 'book_title', 'author', 'publication_date', 'genre', 'summary'])

# %%
books.head(1)
# Out:
#   book_id freebase_id   book_title         author publication_date  \
# 0     620     /m/0hhy  Animal Farm  George Orwell       1945-08-17
#
#                                                genre  \
# 0  {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
#
#                                              summary
# 0   Old Major, the old boar on the Manor Farm, ca...

# %%
books.genre.at[0]
# Out:
# '{"/m/016lj8": "Roman \\u00e0 clef", "/m/06nbt": "Satire", "/m/0dwly": "Children\'s literature", "/m/014dfn": "Speculative fiction", "/m/02xlf": "Fiction"}'

# %%
def parse_genre_entry(genre_info):
    if genre_info == '':
        return []
    genre_dict = json.loads(genre_info)
    genres = list(genre_dict.values())
    return genres

books['genre'] = books['genre'].apply(parse_genre_entry)

# %%
books = books.drop(columns=['freebase_id'])

# %%
books
# Out:
#         book_id                                         book_title  \
# 0           620                                        Animal Farm
# 1           843                                 A Clockwork Orange
# 2           986                                         The Plague
# 3          1756          An Enquiry Concerning Human Understanding
# 4          2080                               A Fire Upon the Deep
# ...         ...                                                ...
# 16554  36934824                                     Under Wildwood
# 16555  37054020                                  Transfer of Power
# 16556  37122323                                            Decoded
# 16557  37132319  America Again: Re-becoming The Greatness We Ne...
# 16558  37159503                                          Poor Folk
#
#                    author publication_date  \
# 0           George Orwell       1945-08-17
# 1         Anthony Burgess             1962
# 2            Albert Camus             1947
# 3              David Hume
# 4            Vernor Vinge
# ...                   ...              ...
# 16554         Colin Meloy       2012-09-25
# 16555         Vince Flynn       2000-06-01
# 16556               Jay-Z       2010-11-16
# 16557     Stephen Colbert       2012-10-02
# 16558  Fyodor Dostoyevsky             1846
#
#                                                    genre  \
# 0      [Roman à clef, Satire, Children's literature, ...
# 1      [Science Fiction, Novella, Speculative fiction...
# 2      [Existentialism, Fiction, Absurdist fiction, N...
# 3                                                     []
# 4      [Hard science fiction, Science Fiction, Specul...
# ...                                                  ...
# 16554                                                 []
# 16555                                [Thriller, Fiction]
# 16556                                    [Autobiography]
# 16557                                                 []
# 16558            [Epistolary novel, Speculative fiction]
#
#                                                  summary
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 3       The argument of the Enquiry proceeds by a ser...
# 4       The novel posits that space around the Milky ...
# ...                                                  ...
# 16554   Prue McKeel, having rescued her brother from ...
# 16555   The reader first meets Rapp while he is doing...
# 16556   The book follows very rough chronological ord...
# 16557   Colbert addresses topics including Wall Stree...
# 16558   Makar Devushkin and Varvara Dobroselova are s...
#
# [16559 rows x 6 columns]

# %%
def clean_ids(x):
    try:
        return int(x)
    except:
        return np.nan

books[''] = books['book_id'].apply(clean_ids)
books = books[books['book_id'].notnull()]

# %%
def book_soup(x):
    genres = ""
    for genre in x[5]:
        genres += genre + " "
    return f"{x['book_title']} {genres} {x['summary']}"

# %%
books["soup"] = books.apply(book_soup, axis=1)
books.sample()
# Out:
#         book_id                 book_title          author publication_date  \
# 13684  21719995  The Covent Garden Tragedy  Henry Fielding
#
#       genre                                            summary            \
# 13684    []   The play deals with a love triangle in a brot...  21719995
#
#                                                     soup
# 13684  The Covent Garden Tragedy   T h e   p l a y   ...

# %%
books.shape[0]
# Out:
# 16559

# %% [markdown]
# ---
# ### Taylor Swift Songs Dataset

# %%
ts_1 = pd.read_csv("01-taylor_swift.csv")
ts_2 = pd.read_csv("02-fearless_taylors_version.csv")
ts_3 = pd.read_csv("03-speak_now_deluxe_package.csv")
ts_4 = pd.read_csv("04-red_deluxe_edition.csv")
ts_5 = pd.read_csv("05-1989_deluxe.csv")
ts_6 = pd.read_csv("06-reputation.csv")
ts_7 = pd.read_csv("07-lover.csv")
ts_8 = pd.read_csv("08-folklore_deluxe_version.csv")
ts_9 = pd.read_csv("09-evermore_deluxe_version.csv")

lyrics = pd.concat([ts_1, ts_2, ts_3, ts_4, ts_5, ts_6, ts_7, ts_8, ts_9])
lyrics.reset_index(drop=True, inplace=True)

# %%
lyrics.sample(5)
# Out:
#                        album_name                 track_title  track_n  \
# 654   Fearless (Taylor’s Version)  Fifteen (Taylor’s Version)        2
# 4852                   reputation            ...Ready for It?        1
# 5721                   reputation       Call It What You Want       14
# 4969                   reputation         I Did Something Bad        3
# 6631                        Lover                         ME!       16
#
#                                                   lyric  line
# 654   Hopin' one of those senior boys will wink at y...     7
# 4852                                  So I take my time    51
# 5721                  Holding my breath, slowly, I said    50
# 4969                   I can feel the flames on my skin    28
# 6631                        Strike the band up, 1, 2, 3    60

# %%
lyrics = lyrics.drop(columns=['line'])

lyrics = lyrics.groupby('track_title').agg({
    'album_name': 'first',  # You can use 'first' to retain the first occurrence of the author
    'track_n': 'first',
     'lyric': ' '.join
}).reset_index()

lyrics.drop_duplicates(subset=['lyric'])

lyrics['lyric']
# Out:
# 0      Knew he was a killer first time that I saw him...
# 1      It feels like a perfect night To dress up like...
# 2      Why would you wanna break a perfectly good hea...
# 3      I don't know what I want, so don't ask me 'Cau...
# 4      I blew things out of proportion, now you're bl...
#                              ...
# 158    Friends break up, friends get married Stranger...
# 159    Is it romantic how all my elegies eulogize me?...
# 160    Rebekah rode up on the afternoon train, it was...
# 161    I sit and watch you reading with your head low...
# 162    If I wanted to know who you were hanging with ...
# Name: lyric, Length: 163, dtype: object

# %%
def lyrics_soup(x):
    return x['album_name'] + " " + x['track_title']  + " " + x['lyric']

# %%
lyrics["soup"] = lyrics.apply(lyrics_soup, axis=1)
lyrics.sample()
# Out:
#    track_title    album_name  track_n  \
# 74    Our Song  Taylor Swift       11
#
#                                                 lyric  \
# 74  I was ridin' shotgun with my hair undone In th...
#
#                                                  soup
# 74  Taylor Swift Our Song I was ridin' shotgun wit...

# %% [markdown]
# ---
# ### Creating Similarity Matrices

# %%
books_lyrics_soups = pd.concat([books['soup'], lyrics['soup']],ignore_index=True)

# %%
books_lyrics_count = CountVectorizer(stop_words = "english")
books_lyrics_count.fit(books_lyrics_soups)

books_to_lyrics_matrix = books_lyrics_count.transform(books['soup'])
lyrics_to_books_matrix = books_lyrics_count.transform(lyrics['soup'])

print(books_to_lyrics_matrix.shape, lyrics_to_books_matrix.shape)
# Out:
# (16559, 122097) (163, 122097)

# %%
cosine_sim_books_lyrics = cosine_similarity(books_to_lyrics_matrix, lyrics_to_books_matrix)
cosine_sim_books_lyrics
# Out:
# array([[0.00648568, 0.01462985, 0.01007148, ..., 0.01811943, 0.01946311,
#         0.01733723],
#        [0.01403105, 0.00852527, 0.01447489, ..., 0.02969649, 0.01801338,
#         0.02746737],
#        [0.03839536, 0.00523713, 0.02340006, ..., 0.09851085, 0.01521539,
#         0.02443731],
#        ...,
#        [0.00646369, 0.01080017, 0.00514734, ..., 0.        , 0.03423018,
#         0.01279884],
#        [0.        , 0.        , 0.00838679, ..., 0.        , 0.        ,
#         0.        ],
#        [0.0226413 , 0.01592899, 0.01850484, ..., 0.07768074, 0.03786412,
#         0.04601215]])

# %%
cosine_sim_lyrics_books = cosine_similarity(lyrics_to_books_matrix, books_to_lyrics_matrix)
cosine_sim_lyrics_books
# Out:
# array([[0.00648568, 0.01403105, 0.03839536, ..., 0.00646369, 0.        ,
#         0.0226413 ],
#        [0.01462985, 0.00852527, 0.00523713, ..., 0.01080017, 0.        ,
#         0.01592899],
#        [0.01007148, 0.01447489, 0.02340006, ..., 0.00514734, 0.00838679,
#         0.01850484],
#        ...,
#        [0.01811943, 0.02969649, 0.09851085, ..., 0.        , 0.        ,
#         0.07768074],
#        [0.01946311, 0.01801338, 0.01521539, ..., 0.03423018, 0.        ,
#         0.03786412],
#        [0.01733723, 0.02746737, 0.02443731, ..., 0.01279884, 0.        ,
#         0.04601215]])

# %%
books = books.reset_index()
books_indices = pd.Series(books.index, index=books['book_title'].apply(lambda x: x.lower() if x is not np.nan else "")).drop_duplicates()

books.head()
# Out:
#    index book_id                                 book_title           author  \
# 0      0     620                                Animal Farm    George Orwell
# 1      1     843                         A Clockwork Orange  Anthony Burgess
# 2      2     986                                 The Plague     Albert Camus
# 3      3    1756  An Enquiry Concerning Human Understanding       David Hume
# 4      4    2080                       A Fire Upon the Deep     Vernor Vinge
#
#   publication_date                                              genre  \
# 0       1945-08-17  [Roman à clef, Satire, Children's literature, ...
# 1             1962  [Science Fiction, Novella, Speculative fiction...
# 2             1947  [Existentialism, Fiction, Absurdist fiction, N...
# 3                                                                  []
# 4                   [Hard science fiction, Science Fiction, Specul...
#
#                                              summary        \
# 0   Old Major, the old boar on the Manor Farm, ca...   620
# 1   Alex, a teenager living in near-future Englan...   843
# 2   The text of The Plague is divided into five p...   986
# 3   The argument of the Enquiry proceeds by a ser...  1756
# 4   The novel posits that space around the Milky ...  2080
#
#                                                 soup
# 0  Animal Farm   O l d   M a j o r ,   t h e   o ...
# 1  A Clockwork Orange   A l e x ,   a   t e e n a...
# 2  The Plague   T h e   t e x t   o f   T h e   P...
# 3  An Enquiry Concerning Human Understanding   T ...
# 4  A Fire Upon the Deep   T h e   n o v e l   p o...

# %%
lyrics = lyrics.reset_index()
lyrics_indices = pd.Series(lyrics.index, index=lyrics['track_title'].apply(lambda x: x.lower() if x is not np.nan else "")).drop_duplicates()

lyrics.head()
# Out:
#    index             track_title            album_name  track_n  \
# 0      0        ...Ready for It?            reputation        1
# 1      1                      22  Red (Deluxe Edition)        6
# 2      2  A Perfectly Good Heart          Taylor Swift       14
# 3      3   A Place In This World          Taylor Swift        4
# 4      4               Afterglow                 Lover       15
#
#                                                lyric  \
# 0  Knew he was a killer first time that I saw him...
# 1  It feels like a perfect night To dress up like...
# 2  Why would you wanna break a perfectly good hea...
# 3  I don't know what I want, so don't ask me 'Cau...
# 4  I blew things out of proportion, now you're bl...
#
#                                                 soup
# 0  reputation ...Ready for It? Knew he was a kill...
# 1  Red (Deluxe Edition) 22 It feels like a perfec...
# 2  Taylor Swift A Perfectly Good Heart Why would ...
# 3  Taylor Swift A Place In This World I don't kno...
# 4  Lover Afterglow I blew things out of proportio...

# %%
class RecommendationEngine:
    def get_books_from_lyrics(title):
        try:
            idx = lyrics_indices[title.lower()]
            sim_scores = list(enumerate(cosine_sim_lyrics_books[idx]))
            sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)

            sim_scores = sim_scores[:5]

            book_indices = [i[0] for i in sim_scores]

            return books.iloc[book_indices]
        except :
            print("No song found in our database. Please try again.")

    def get_lyrics_from_books(title):
        try:
            idx = books_indices[title.lower()]
            sim_scores = list(enumerate(cosine_sim_books_lyrics[idx]))
            sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)

            sim_scores = sim_scores[:5]

            lyrics_indices = [i[0] for i in sim_scores]

            return lyrics.iloc[lyrics_indices]
        except :
            print("No book found in our database. Please try again.")

# %%
rand = books["book_title"].sample(1).values[0]
rand
# Out:
# 'Tomorrow'

# %%
RecommendationEngine.get_lyrics_from_books(rand)
# Out:
#     index               track_title          album_name  track_n  \
# 54     54                 Invisible        Taylor Swift       13
# 3       3     A Place In This World        Taylor Swift        4
# 62     62  Look What You Made Me Do          reputation        6
# 60     60                London Boy               Lover       11
# 71     71             Never Grow Up  Speak Now (Deluxe)        8
#
#                                                 lyric  \
# 54  She can't see the way your eyes Light up when ...
# 3   I don't know what I want, so don't ask me 'Cau...
# 62  I don't like your little games Don't like your...
# 60  We can go driving in, on my scooter Uh, you kn...
# 71  Your little hand's wrapped around my finger An...
#
#                                                  soup
# 54  Taylor Swift Invisible She can't see the way y...
# 3   Taylor Swift A Place In This World I don't kno...
# 62  reputation Look What You Made Me Do I don't li...
# 60  Lover London Boy We can go driving in, on my s...
# 71  Speak Now (Deluxe) Never Grow Up Your little h...

# %%
RecommendationEngine.get_lyrics_from_books('The Ramsay Scallop')
# Out:
#      index       track_title                 album_name  track_n  \
# 39      39      Girl at Home       Red (Deluxe Edition)       19
# 50      50  I Think He Knows                      Lover        6
# 75      75              Ours         Speak Now (Deluxe)       15
# 133    133              hoax  folklore (deluxe version)       16
# 130    130          cardigan  folklore (deluxe version)        2
#
#                                                  lyric  \
# 39   Don't look at me, you got a girl at home And e...
# 50   I think he knows His footprints on the sidewal...
# 75   Elevator buttons and morning air Strangers' si...
# 133  My only one My smoking gun My eclipsed sun Thi...
# 130  Vintage tee, brand new phone High heels on cob...
#
#                                                   soup
# 39   Red (Deluxe Edition) Girl at Home Don't look a...
# 50   Lover I Think He Knows I think he knows His fo...
# 75   Speak Now (Deluxe) Ours Elevator buttons and m...
# 133  folklore (deluxe version) hoax My only one My ...
# 130  folklore (deluxe version) cardigan Vintage tee...

# %%
rand = lyrics["track_title"].sample(1).values[0]
rand
# Out:
# "Should've Said No"

# %%
RecommendationEngine.get_books_from_lyrics(rand)
# Out:
#        index   book_id                book_title               author  \
# 7472    7472   6727906                       M/F      Anthony Burgess
# 13712  13712  21802138       For Lust of Knowing  Robert Graham Irwin
# 9451    9451  10254205  Five Go Off In A Caravan          Enid Blyton
# 1762    1762    872478               Kate Vaiden       Reynolds Price
# 3374    3374   2192851    The Thief and the Dogs       Naguib Mahfouz
#
#       publication_date                               genre  \
# 7472              1971  [Comic novel, Speculative fiction]
# 13712             2006                       [Non-fiction]
# 9451              1946          [Mystery, Adventure novel]
# 1762           1986-06                    [Fiction, Novel]
# 3374              1961                             [Novel]
#
#                                                  summary            \
# 7472    From the blurb of Cape's first edition 'The s...   6727906
# 13712   While For Lust of Knowing is a riposte to Sai...  21802138
# 9451    A caravan holiday for the Famous Five! It is ...  10254205
# 1762    Kate Vaiden is the first person narrator of t...    872478
# 3374    Said's world revolves around Nabawiyya, his f...   2192851
#
#                                                     soup
# 7472   M/F   F r o m   t h e   b l u r b   o f   C a ...
# 13712  For Lust of Knowing   W h i l e   F o r   L u ...
# 9451   Five Go Off In A Caravan   A   c a r a v a n  ...
# 1762   Kate Vaiden   K a t e   V a i d e n   i s   t ...
# 3374   The Thief and the Dogs   S a i d ' s   w o r l...

# %%
RecommendationEngine.get_books_from_lyrics('Back to December')
# Out:
#        index   book_id           book_title             author  \
# 963      963    380013       The Time Ships     Stephen Baxter
# 10643  10643  13139490        Let Time Pass  Svend Aage Madsen
# 3827    3827   2611550  A Tale of Time City  Diana Wynne Jones
# 12112  12112  17139588          The Fermata    Nicholson Baker
# 4947    4947   3744486    The Longest Night   J. N. Williamson
#
#       publication_date                                              genre  \
# 963               1995  [Science Fiction, Novel, Alternate history, Sp...
# 10643                                                             [Novel]
# 3827              1987  [Science Fiction, Children's literature, Fanta...
# 12112                               [Speculative fiction, Fiction, Novel]
# 4947        2002-12-02             [Fantasy, Speculative fiction, Horror]
#
#                                                  summary            \
# 963     After the events related in The Time Machine,...    380013
# 10643   Johanna who is a lector at a Danish universit...  13139490
# 3827    It is September, 1939, the start of World War...   2611550
# 12112   Arno Strine discovers he can stop time when h...  17139588
# 4947    It's December 21, and hour by hour Angel and ...   3744486
#
#                                                     soup
# 963    The Time Ships   A f t e r   t h e   e v e n t...
# 10643  Let Time Pass   J o h a n n a   w h o   i s   ...
# 3827   A Tale of Time City   I t   i s   S e p t e m ...
# 12112  The Fermata   A r n o   S t r i n e   d i s c ...
# 4947   The Longest Night   I t ' s   D e c e m b e r ...

# %%
books.sample(5)['book_title']
# Out:
# 5607                               Pamela
# 10124               The House at Riverton
# 16398          Debt: The First 5000 Years
# 3245     The Mystery of the Aztec Warrior
# 6370               Murder Being Once Done
# Name: book_title, dtype: object

# %%
lyrics.sample(5)['track_title']
# Out:
# 124    You All Over Me (Taylor’s Version) [From the V...
# 34                           Fearless (Taylor’s Version)
# 99       That’s When (Taylor’s Version) [From the Vault]
# 56                         I’m Only Me When I’m with You
# 22                           Dancing with Our Hands Tied
# Name: track_title, dtype: object
