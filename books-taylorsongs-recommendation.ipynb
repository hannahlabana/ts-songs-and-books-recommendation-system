# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# %matplotlib inline
# import ipywidgets
import csv
import json
import spacy
nlp = spacy.load('en_core_web_sm')
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
import nltk 
from gensim.corpora import Dictionary
from gensim.models import Phrases
from gensim.models.phrases import Phraser
from gensim import models
import re
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ---
# ### Books Dataset

# %%
data =[]
with open('booksummaries.txt','r', encoding='utf-8') as f:
    reader = csv.reader(f, dialect='excel-tab')
    for row in reader:
        data.append(row)

books = pd.DataFrame.from_records(data, columns=['book_id', 'freebase_id', 'book_title', 'author', 'publication_date', 'genre', 'summary'])

# %%
def parse_genre_entry(genre_info):
    if genre_info is None or genre_info == '':
        return []
    genre_dict = json.loads(genre_info)
    genres = list(genre_dict.values())
    return genres

books['genre'] = books['genre'].apply(parse_genre_entry)

# %%
books = books.drop(columns=['freebase_id'])

# %%
books.head(3)
# Out:
#   book_id          book_title           author publication_date  \
# 0     620         Animal Farm    George Orwell       1945-08-17
# 1     843  A Clockwork Orange  Anthony Burgess             1962
# 2     986          The Plague     Albert Camus             1947
#
#                                                genre  \
# 0  [Roman à clef, Satire, Children's literature, ...
# 1  [Science Fiction, Novella, Speculative fiction...
# 2  [Existentialism, Fiction, Absurdist fiction, N...
#
#                                              summary
# 0   Old Major, the old boar on the Manor Farm, ca...
# 1   Alex, a teenager living in near-future Englan...
# 2   The text of The Plague is divided into five p...

# %%
def clean_ids(x):
    try:
        return int(x)
    except:
        return np.nan

books[''] = books['book_id'].apply(clean_ids)
books = books[books['book_id'].notnull()]

# %%
def contains_romance(genres):
    if genres is None:
        return False
    return any('romance' in genre.lower() for genre in genres)

rom_books = books[books['genre'].apply(contains_romance)]

# %%
books.shape
# Out:
# (488, 7)

# %%
def book_soup(x):
    genres = ""
    for genre in x['genre']:
        genres += genre + " "
    return f"{x['book_title']} {genres} {x['summary']}"

# %%
books["DOCUMENT"] = books.apply(book_soup, axis=1)

# %%
def preprocess_text(text):
    # lowercasing
    lowercased_text = text.lower()

    # cleaning 
    remove_punctuation = re.sub(r'[^\w\s]', '', lowercased_text)
    remove_white_space = remove_punctuation.strip()

    # Tokenization
    tokenized_text = word_tokenize(remove_white_space)

    # Stop Words
    from nltk.corpus import stopwords
    stopwords = set(stopwords.words('english'))
    stopwords_removed = [word for word in tokenized_text if word not in stopwords]

    # Stemming
    ps = PorterStemmer()
    stemmed_text = [ps.stem(word) for word in stopwords_removed]

    return {
        'DOCUMENT': text,
        'LOWERCASE': lowercased_text,
        'CLEANING': remove_white_space,
        'TOKENIZATION': tokenized_text,
        'STOP-WORDS': stopwords_removed,
        'STEMMING': stemmed_text
    }
 
    # return df

def preprocessing(corpus, corpus_type):
    preprocessed_data = []

    # Running preprocessing one by one
    for doc in corpus['DOCUMENT']:
        # Call the preprocess_text function
        preprocessed_data.append(preprocess_text(doc))

    # Create DataFrame based on corpus_type
    if corpus_type == 'books':
        df = pd.DataFrame({
            'book_id': corpus['book_id'],
            'book_title': corpus['book_title'],
            'author': corpus['author'],
            'publication_date': corpus['publication_date'],
            'genre': corpus['genre'],
            'summary': corpus['summary'],
            'DOCUMENT': [d['DOCUMENT'] for d in preprocessed_data],
            'LOWERCASE': [d['LOWERCASE'] for d in preprocessed_data],
            'CLEANING': [d['CLEANING'] for d in preprocessed_data],
            'TOKENIZATION': [d['TOKENIZATION'] for d in preprocessed_data],
            'STOP-WORDS': [d['STOP-WORDS'] for d in preprocessed_data],
            'STEMMING': [d['STEMMING'] for d in preprocessed_data]
        })
    else:
        df = pd.DataFrame({
            'track_title': corpus['track_title'],
            'album_name': corpus['album_name'],
            'track_n': corpus['track_n'],
            'lyric': corpus['lyric'],
            'DOCUMENT': [d['DOCUMENT'] for d in preprocessed_data],
            'LOWERCASE': [d['LOWERCASE'] for d in preprocessed_data],
            'CLEANING': [d['CLEANING'] for d in preprocessed_data],
            'TOKENIZATION': [d['TOKENIZATION'] for d in preprocessed_data],
            'STOP-WORDS': [d['STOP-WORDS'] for d in preprocessed_data],
            'STEMMING': [d['STEMMING'] for d in preprocessed_data]
        })

    return df

# %%
books_result_preprocessing = preprocessing(books, 'books')

# %%
def soup_after_lemma(x):
    soups = ""
    for text in x['STEMMING']:
        soups += text + " "
    return soups

# %%
books_result_preprocessing["STEMMING"] = books_result_preprocessing.apply(soup_after_lemma, axis=1)

# %% [markdown]
# ---
# ### Taylor Swift Songs Dataset

# %%
ts_1 = pd.read_csv("01-taylor_swift.csv")
ts_2 = pd.read_csv("02-fearless_taylors_version.csv")
ts_3 = pd.read_csv("03-speak_now_deluxe_package.csv")
ts_4 = pd.read_csv("04-red_deluxe_edition.csv")
ts_5 = pd.read_csv("05-1989_deluxe.csv")
ts_6 = pd.read_csv("06-reputation.csv")
ts_7 = pd.read_csv("07-lover.csv")
ts_8 = pd.read_csv("08-folklore_deluxe_version.csv")
ts_9 = pd.read_csv("09-evermore_deluxe_version.csv")

lyrics = pd.concat([ts_1, ts_2, ts_3, ts_4, ts_5, ts_6, ts_7, ts_8, ts_9])
lyrics.reset_index(drop=True, inplace=True)

# %%
lyrics = lyrics.drop(columns=['line'])

lyrics = lyrics.groupby('track_title').agg({
    'album_name': 'first',
    'track_n': 'first',
     'lyric': ' '.join
}).reset_index()

lyrics.drop_duplicates(subset=['lyric'])
# Out:
#                           track_title                 album_name  track_n  \
# 0                    ...Ready for It?                 reputation        1
# 1                                  22       Red (Deluxe Edition)        6
# 2              A Perfectly Good Heart               Taylor Swift       14
# 3               A Place In This World               Taylor Swift        4
# 4                           Afterglow                      Lover       15
# ..                                ...                        ...      ...
# 158         ​r​ight where you left me  evermore (deluxe version)       16
# 159                        ​the lakes  folklore (deluxe version)       17
# 160  ​the last great american dynasty  folklore (deluxe version)        3
# 161                      ​tolerate it  evermore (deluxe version)        5
# 162             ​’tis the damn season  evermore (deluxe version)        4
#
#                                                  lyric
# 0    Knew he was a killer first time that I saw him...
# 1    It feels like a perfect night To dress up like...
# 2    Why would you wanna break a perfectly good hea...
# 3    I don't know what I want, so don't ask me 'Cau...
# 4    I blew things out of proportion, now you're bl...
# ..                                                 ...
# 158  Friends break up, friends get married Stranger...
# 159  Is it romantic how all my elegies eulogize me?...
# 160  Rebekah rode up on the afternoon train, it was...
# 161  I sit and watch you reading with your head low...
# 162  If I wanted to know who you were hanging with ...
#
# [163 rows x 4 columns]

# %%
for index, row in lyrics.iterrows():
    print(index,row['track_title'])
# Out:
# 0 ...Ready for It?
# 1 22
# 2 A Perfectly Good Heart
# 3 A Place In This World
# 4 Afterglow
# 5 All Too Well
# 6 All You Had to Do Was Stay
# 7 Back to December
# 8 Bad Blood
# 9 Begin Again
# 10 Better Than Revenge
# 11 Blank Space
# 12 Breathe (Taylor’s Version)
# 13 Bye Bye Baby (Taylor’s Version) [From the Vault]
# 14 Call It What You Want
# 15 Change (Taylor’s Version)
# 16 Clean
# 17 Cold As You
# 18 Come Back... Be Here
# 19 Come In With the Rain (Taylor’s Version)
# 20 Cornelia Street
# 21 Cruel Summer
# 22 Dancing with Our Hands Tied
# 23 Daylight
# 24 Dear John
# 25 Death by a Thousand Cuts
# 26 Delicate
# 27 Don’t Blame Me
# 28 Don’t You (Taylor’s Version) [From the Vault]
# 29 Dress
# 30 Enchanted
# 31 End Game
# 32 Everything Has Changed
# 33 False God
# 34 Fearless (Taylor’s Version)
# 35 Fifteen (Taylor’s Version)
# 36 Forever & Always (Piano Version) [Taylor’s Version]
# 37 Forever & Always (Taylor’s Version)
# 38 Getaway Car
# 39 Girl at Home
# 40 Gorgeous
# 41 Haunted
# 42 Hey Stephen (Taylor’s Version)
# 43 Holy Ground
# 44 How You Get the Girl
# 45 I Almost Do
# 46 I Did Something Bad
# 47 I Forgot That You Existed
# 48 I Knew You Were Trouble
# 49 I Know Places
# 50 I Think He Knows
# 51 I Wish You Would
# 52 If This Was a Movie
# 53 Innocent
# 54 Invisible
# 55 It’s Nice to Have a Friend
# 56 I’m Only Me When I’m with You
# 57 Jump Then Fall (Taylor’s Version)
# 58 King of My Heart
# 59 Last Kiss
# 60 London Boy
# 61 Long Live
# 62 Look What You Made Me Do
# 63 Love Story (Taylor’s Version)
# 64 Lover
# 65 ME!
# 66 Mary’s Song (Oh My My My)
# 67 Mean
# 68 Mine
# 69 Miss Americana & The Heartbreak Prince
# 70 Mr. Perfectly Fine (Taylor’s Version) [From the Vault]
# 71 Never Grow Up
# 72 New Romantics
# 73 New Year’s Day
# 74 Our Song
# 75 Ours
# 76 Out of the Woods
# 77 Paper Rings
# 78 Picture To Burn
# 79 Red
# 80 Red (Original Demo Recording)
# 81 Sad Beautiful Tragic
# 82 Shake It Off
# 83 Should've Said No
# 84 So It Goes...
# 85 Soon You’ll Get Better
# 86 Sparks Fly
# 87 Speak Now
# 88 Starlight
# 89 State of Grace
# 90 State of Grace (Acoustic Version)
# 91 Stay Beautiful
# 92 Stay Stay Stay
# 93 Style
# 94 Superman
# 95 Superstar (Taylor’s Version)
# 96 Teardrops On My Guitar
# 97 Teardrops on My Guitar (Pop Version)
# 98 Tell Me Why (Taylor’s Version)
# 99 That’s When (Taylor’s Version) [From the Vault]
# 100 The Archer
# 101 The Best Day (Taylor’s Version)
# 102 The Last Time
# 103 The Lucky One
# 104 The Man
# 105 The Moment I Knew
# 106 The Other Side of the Door (Taylor’s Version)
# 107 The Outside
# 108 The Story of Us
# 109 The Way I Loved You (Taylor’s Version)
# 110 This Is Why We Can’t Have Nice Things
# 111 This Love
# 112 Tied Together With A Smile
# 113 Tim McGraw
# 114 Today Was a Fairytale (Taylor’s Version)
# 115 Treacherous
# 116 Treacherous (Original Demo Recording)
# 117 Untouchable (Taylor’s Version)
# 118 We Are Never Ever Getting Back Together
# 119 We Were Happy (Taylor’s Version) [From the Vault]
# 120 Welcome to New York
# 121 White Horse (Taylor’s Version)
# 122 Wildest Dreams
# 123 Wonderland
# 124 You All Over Me (Taylor’s Version) [From the Vault]
# 125 You Are in Love
# 126 You Belong With Me (Taylor’s Version)
# 127 You Need To Calm Down
# 128 You’re Not Sorry (Taylor’s Version)
# 129 august
# 130 cardigan
# 131 champagne problems
# 132 cowboy like me
# 133 hoax
# 134 my tears ricochet
# 135 seven
# 136 the 1
# 137 this is me trying
# 138 willow
# 139 ​betty
# 140 ​closure
# 141 ​coney island
# 142 ​dorothea
# 143 ​epiphany
# 144 ​evermore
# 145 ​exile
# 146 ​gold rush
# 147 ​happiness
# 148 ​illicit affairs
# 149 ​invisible string
# 150 ​it’s time to go
# 151 ​ivy
# 152 ​l​ong story short
# 153 ​mad woman
# 154 ​marjorie
# 155 ​mirrorball
# 156 ​no body, no crime
# 157 ​peace
# 158 ​r​ight where you left me
# 159 ​the lakes
# 160 ​the last great american dynasty
# 161 ​tolerate it
# 162 ​’tis the damn season

# %%
lyrics = lyrics.drop(index=[36,80,90,97,116])

# %%
lyrics = lyrics.reset_index()
for index, row in lyrics.iterrows():
    print(index,row['track_title'])
# Out:
# 0 ...Ready for It?
# 1 22
# 2 A Perfectly Good Heart
# 3 A Place In This World
# 4 Afterglow
# 5 All Too Well
# 6 All You Had to Do Was Stay
# 7 Back to December
# 8 Bad Blood
# 9 Begin Again
# 10 Better Than Revenge
# 11 Blank Space
# 12 Breathe (Taylor’s Version)
# 13 Bye Bye Baby (Taylor’s Version) [From the Vault]
# 14 Call It What You Want
# 15 Change (Taylor’s Version)
# 16 Clean
# 17 Cold As You
# 18 Come Back... Be Here
# 19 Come In With the Rain (Taylor’s Version)
# 20 Cornelia Street
# 21 Cruel Summer
# 22 Dancing with Our Hands Tied
# 23 Daylight
# 24 Dear John
# 25 Death by a Thousand Cuts
# 26 Delicate
# 27 Don’t Blame Me
# 28 Don’t You (Taylor’s Version) [From the Vault]
# 29 Dress
# 30 Enchanted
# 31 End Game
# 32 Everything Has Changed
# 33 False God
# 34 Fearless (Taylor’s Version)
# 35 Fifteen (Taylor’s Version)
# 36 Forever & Always (Taylor’s Version)
# 37 Getaway Car
# 38 Girl at Home
# 39 Gorgeous
# 40 Haunted
# 41 Hey Stephen (Taylor’s Version)
# 42 Holy Ground
# 43 How You Get the Girl
# 44 I Almost Do
# 45 I Did Something Bad
# 46 I Forgot That You Existed
# 47 I Knew You Were Trouble
# 48 I Know Places
# 49 I Think He Knows
# 50 I Wish You Would
# 51 If This Was a Movie
# 52 Innocent
# 53 Invisible
# 54 It’s Nice to Have a Friend
# 55 I’m Only Me When I’m with You
# 56 Jump Then Fall (Taylor’s Version)
# 57 King of My Heart
# 58 Last Kiss
# 59 London Boy
# 60 Long Live
# 61 Look What You Made Me Do
# 62 Love Story (Taylor’s Version)
# 63 Lover
# 64 ME!
# 65 Mary’s Song (Oh My My My)
# 66 Mean
# 67 Mine
# 68 Miss Americana & The Heartbreak Prince
# 69 Mr. Perfectly Fine (Taylor’s Version) [From the Vault]
# 70 Never Grow Up
# 71 New Romantics
# 72 New Year’s Day
# 73 Our Song
# 74 Ours
# 75 Out of the Woods
# 76 Paper Rings
# 77 Picture To Burn
# 78 Red
# 79 Sad Beautiful Tragic
# 80 Shake It Off
# 81 Should've Said No
# 82 So It Goes...
# 83 Soon You’ll Get Better
# 84 Sparks Fly
# 85 Speak Now
# 86 Starlight
# 87 State of Grace
# 88 Stay Beautiful
# 89 Stay Stay Stay
# 90 Style
# 91 Superman
# 92 Superstar (Taylor’s Version)
# 93 Teardrops On My Guitar
# 94 Tell Me Why (Taylor’s Version)
# 95 That’s When (Taylor’s Version) [From the Vault]
# 96 The Archer
# 97 The Best Day (Taylor’s Version)
# 98 The Last Time
# 99 The Lucky One
# 100 The Man
# 101 The Moment I Knew
# 102 The Other Side of the Door (Taylor’s Version)
# 103 The Outside
# 104 The Story of Us
# 105 The Way I Loved You (Taylor’s Version)
# 106 This Is Why We Can’t Have Nice Things
# 107 This Love
# 108 Tied Together With A Smile
# 109 Tim McGraw
# 110 Today Was a Fairytale (Taylor’s Version)
# 111 Treacherous
# 112 Untouchable (Taylor’s Version)
# 113 We Are Never Ever Getting Back Together
# 114 We Were Happy (Taylor’s Version) [From the Vault]
# 115 Welcome to New York
# 116 White Horse (Taylor’s Version)
# 117 Wildest Dreams
# 118 Wonderland
# 119 You All Over Me (Taylor’s Version) [From the Vault]
# 120 You Are in Love
# 121 You Belong With Me (Taylor’s Version)
# 122 You Need To Calm Down
# 123 You’re Not Sorry (Taylor’s Version)
# 124 august
# 125 cardigan
# 126 champagne problems
# 127 cowboy like me
# 128 hoax
# 129 my tears ricochet
# 130 seven
# 131 the 1
# 132 this is me trying
# 133 willow
# 134 ​betty
# 135 ​closure
# 136 ​coney island
# 137 ​dorothea
# 138 ​epiphany
# 139 ​evermore
# 140 ​exile
# 141 ​gold rush
# 142 ​happiness
# 143 ​illicit affairs
# 144 ​invisible string
# 145 ​it’s time to go
# 146 ​ivy
# 147 ​l​ong story short
# 148 ​mad woman
# 149 ​marjorie
# 150 ​mirrorball
# 151 ​no body, no crime
# 152 ​peace
# 153 ​r​ight where you left me
# 154 ​the lakes
# 155 ​the last great american dynasty
# 156 ​tolerate it
# 157 ​’tis the damn season

# %%
def lyrics_soup(x):
    return x['album_name'] + " " + x['track_title']  + " " + x['lyric']

# %%
lyrics["DOCUMENT"] = lyrics.apply(lyrics_soup, axis=1)

# %%
lyrics_result_preprocessing = preprocessing(lyrics, 'lyrics')

# %%
lyrics_result_preprocessing["STEMMING"] = lyrics_result_preprocessing.apply(soup_after_lemma, axis=1)

# %% [markdown]
# ---
# ### Creating Similarity Matrices

# %%
lyrics_books_soups = pd.concat([books_result_preprocessing['STEMMING'], lyrics_result_preprocessing['STEMMING']],ignore_index=True)
lyrics_books_soups
# Out:
# 0      pride prejudic satir fiction romanc novel nove...
# 1      sens sensibl children literatur fiction romanc...
# 2      lord ring adventur novel specul fiction fantas...
# 3      time machin scienc fiction children literatur ...
# 4      invis man albino bia scienc fiction children l...
#                              ...
# 641    evermor delux version right left friend break ...
# 642    folklor delux version lake romant elegi eulog ...
# 643    folklor delux version last great american dyna...
# 644    evermor delux version toler sit watch read hea...
# 645    evermor delux version ti damn season want know...
# Name: STEMMING, Length: 646, dtype: object

# %%
# lyrics_books_count = CountVectorizer()
# lyrics_books_count.fit(lyrics_books_soups)

lyrics_books_count = TfidfVectorizer()
lyrics_books_count.fit(lyrics_books_soups)

lyrics_to_books_matrix = lyrics_books_count.transform(lyrics_result_preprocessing['STEMMING'])
books_to_lyrics_matrix = lyrics_books_count.transform(books_result_preprocessing['STEMMING'])

# %%
cosim_result_lyrics_books = cosine_similarity(lyrics_to_books_matrix, books_to_lyrics_matrix)
cosim_result_books_lyrics = cosine_similarity(books_to_lyrics_matrix, lyrics_to_books_matrix)

# %%
books_system = books_result_preprocessing.reset_index()
books_indices = pd.Series(books_system.index, index=books_result_preprocessing['book_title'].apply(lambda x: x.lower() if x is not np.nan else "")).drop_duplicates()

# books_system

# %%
lyrics_system = lyrics_result_preprocessing.reset_index()
lyrics_indices = pd.Series(lyrics_system.index, index=lyrics_result_preprocessing['track_title'].apply(lambda x: x.lower() if x is not np.nan else "")).drop_duplicates()

# lyrics_system.head(3)

# %% [markdown]
# ---
# ### Recommendation System

# %%
def get_books_from_lyrics(title):
    idx = lyrics_indices[title.lower()]
    sim_scores = list(enumerate(cosim_result_lyrics_books[idx]))
    sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)

    sim_scores = sim_scores[:3]


    book_indices = [i[0] for i in sim_scores]
    scores = [i[1] for i in sim_scores]
    # print (scores)

    arr = books_system.iloc[book_indices]

    ctr = 0
    results = []
    for idx, book in arr.iterrows():
        results.append([ctr+1, book['book_title'], scores[ctr], book['summary']])
        ctr += 1

    result_df = pd.DataFrame(results, columns=['Index', 'Book Title', 'Cosine Similarity', 'Summary'])

    return result_df

def get_lyrics_from_books(title):
    idx = books_indices[title.lower()]
    sim_scores = list(enumerate(cosim_result_books_lyrics[idx]))
    sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)

    sim_scores = sim_scores[:3]

    #print(sim_scores)

    lyrics_indices = [i[0] for i in sim_scores]

    scores = [i[1] for i in sim_scores]
    # print (scores)

    arr = lyrics_system.iloc[lyrics_indices]

    ctr = 0;
    results = []
    for idx, lyric in arr.iterrows():
        results.append([ctr+1, lyric['track_title'], scores[ctr], lyric['album_name'], lyric['lyric']])
        ctr += 1

    result_df = pd.DataFrame(results, columns=['Index', 'Track Title', 'Cosine Similarity', 'Album Name', 'Lyric'])

    return result_df

# %% [markdown]
# ---
# ### Examples

# %%
rand = books_system["book_title"].sample(1).values[0]
rand
# Out:
# 'Adam Loveday'

# %%
get_lyrics_from_books(rand)
# Out:
#    Index                      Track Title  Cosine Similarity  \
# 0      1                        Dear John           0.044316
# 1      2  The Best Day (Taylor’s Version)           0.032755
# 2      3                        This Love           0.028813
#
#                     Album Name  \
# 0           Speak Now (Deluxe)
# 1  Fearless (Taylor’s Version)
# 2                1989 (Deluxe)
#
#                                                Lyric
# 0  Long were the nights when My days once revolve...
# 1  I'm five years old, it's getting cold, I've go...
# 2  Clear blue water High tide came and brought yo...

# %%
get_lyrics_from_books("Shannon's Way")
# Out:
#    Index                            Track Title  Cosine Similarity  \
# 0      1  You Belong With Me (Taylor’s Version)           0.083723
# 1      2                             Tim McGraw           0.042890
# 2      3                              Enchanted           0.032664
#
#                     Album Name  \
# 0  Fearless (Taylor’s Version)
# 1                 Taylor Swift
# 2           Speak Now (Deluxe)
#
#                                                Lyric
# 0  You're on the phone with your girlfriend, she'...
# 1  He said the way my blue eyes shined Put those ...
# 2  There I was again tonight Forcing laughter, fa...

# %%
get_lyrics_from_books('Romeo and Juliet')
# Out:
#    Index                               Track Title  Cosine Similarity  \
# 0      1             Love Story (Taylor’s Version)           0.423161
# 1      2    Miss Americana & The Heartbreak Prince           0.025691
# 2      3  Come In With the Rain (Taylor’s Version)           0.021898
#
#                     Album Name  \
# 0  Fearless (Taylor’s Version)
# 1                        Lover
# 2  Fearless (Taylor’s Version)
#
#                                                Lyric
# 0  We were both young when I first saw you I clos...
# 1  You know I adore you, I'm crazier for you Than...
# 2  I could go back to every laugh But I don't wan...

# %%
get_lyrics_from_books('Pride and Prejudice')
# Out:
#    Index                                        Track Title  \
# 0      1  Mr. Perfectly Fine (Taylor’s Version) [From th...
# 1      2                                        Cold As You
# 2      3                                    You Are in Love
#
#    Cosine Similarity                   Album Name  \
# 0           0.288197  Fearless (Taylor’s Version)
# 1           0.018839                 Taylor Swift
# 2           0.017085                1989 (Deluxe)
#
#                                                Lyric
# 0  Mr. "Perfect face" Mr. "Here to stay" Mr. "Loo...
# 1  You have a way of coming easily to me And when...
# 2  One look, dark room Meant just for you Time mo...

# %%
rand = lyrics["track_title"].sample(1).values[0]
rand
# Out:
# '\u200btolerate it'

# %%
get_books_from_lyrics(rand)
# Out:
#    Index                     Book Title  Cosine Similarity  \
# 0      1                   Royal Escape           0.077048
# 1      2  The Gospel According to Larry           0.064674
# 2      3            Unfinished Portrait           0.064462
#
#                                              Summary
# 0   Two years after the execution of his father (...
# 1   The Gospel According to Larry revolves around...
# 2   In the midst of divorce, bereft of the only p...

# %%
get_books_from_lyrics('Mr. Perfectly Fine (Taylor’s Version) [From the Vault]')
# Out:
#    Index           Book Title  Cosine Similarity  \
# 0      1  Pride and Prejudice           0.288197
# 1      2      Nightmare Abbey           0.267108
# 2      3                 Emma           0.224042
#
#                                              Summary
# 0   The narrative opens with Mr Bingley, a wealth...
# 1   Nightmare Abbey is a Gothic topical satire in...
# 2   Emma Woodhouse, aged 20 at the start of the n...

# %%
get_books_from_lyrics('Dancing with Our Hands Tied')
# Out:
#    Index       Book Title  Cosine Similarity  \
# 0      1      Alice Adams           0.127189
# 1      2    Boy Meets Boy           0.117760
# 2      3  Fire in Stubble           0.107932
#
#                                              Summary
# 0   The novel begins with Virgil Adams confined t...
# 1   Openly gay sophomore Paul lives in a gay-frie...
# 2   The book centres on the love life of Rose Mar...

# %%
get_books_from_lyrics('Paper Rings')
# Out:
#    Index                     Book Title  Cosine Similarity  \
# 0      1          The Lord of the Rings           0.088379
# 1      2  The Gospel According to Larry           0.085270
# 2      3           Undead and Unpopular           0.073222
#
#                                              Summary
# 0   Long before the events of the novel, the Dark...
# 1   The Gospel According to Larry revolves around...
# 2   Betsy Taylor, Queen of Vampires, is celebrati...

# %%
books_system.sample(5)['book_title']
# Out:
# 320               Eva Luna
# 230                Indiana
# 77     The Kreutzer Sonata
# 451              Heartless
# 104               Scarlett
# Name: book_title, dtype: object

# %%
lyrics_system.sample(5)['track_title']
# Out:
# 73                   Our Song
# 2      A Perfectly Good Heart
# 52                   Innocent
# 144         ​invisible string
# 146                      ​ivy
# Name: track_title, dtype: object
