# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# %matplotlib inline
import ipywidgets
import csv
import json
import spacy
nlp = spacy.load('en_core_web_sm')
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
import nltk 
import string
from gensim.corpora import Dictionary
from gensim.models import Phrases
from gensim.models.phrases import Phraser

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ---
# ### Books Dataset

# %%
data =[]
with open('booksummaries.txt','r', encoding='utf-8') as f:
    reader = csv.reader(f, dialect='excel-tab')
    for row in reader:
        data.append(row)

books = pd.DataFrame.from_records(data, columns=['book_id', 'freebase_id', 'book_title', 'author', 'publication_date', 'genre', 'summary'])

# %%
def parse_genre_entry(genre_info):
    if genre_info == '':
        return []
    genre_dict = json.loads(genre_info)
    genres = list(genre_dict.values())
    return genres

books['genre'] = books['genre'].apply(parse_genre_entry)

# %%
books = books.drop(columns=['freebase_id'])

# %%
books.head(3)
# Out:
#   book_id          book_title           author publication_date  \
# 0     620         Animal Farm    George Orwell       1945-08-17
# 1     843  A Clockwork Orange  Anthony Burgess             1962
# 2     986          The Plague     Albert Camus             1947
#
#                                                genre  \
# 0  [Roman à clef, Satire, Children's literature, ...
# 1  [Science Fiction, Novella, Speculative fiction...
# 2  [Existentialism, Fiction, Absurdist fiction, N...
#
#                                              summary
# 0   Old Major, the old boar on the Manor Farm, ca...
# 1   Alex, a teenager living in near-future Englan...
# 2   The text of The Plague is divided into five p...

# %%
def clean_ids(x):
    try:
        return int(x)
    except:
        return np.nan

books[''] = books['book_id'].apply(clean_ids)
books = books[books['book_id'].notnull()]

# %%
books.shape[0]
# Out:
# 16559

# %%
books = books.sample(5000)
books.shape[0]
# Out:
# 5000

# %%
def book_soup(x):
    genres = ""
    for genre in x['genre']:
        genres += genre + " "
    return f"{x['book_title']} {genres} {x['summary']}"

# %%
books["soup"] = books.apply(book_soup, axis=1)
# books.sample()

books.iloc[635]
# Out:
# book_id                                                      15290077
# book_title                                       Waiting for The Rain
# author                                                  Sheila Gordon
# publication_date
# genre                                         [Children's literature]
# summary              When the book begins, Tengo and Frikkie are t...
#                                                              15290077
# soup                Waiting for The Rain Children's literature   W...
# Name: 11509, dtype: object

# %%
def sanitize(x):
    if isinstance(x, list):
        return [str.lower(i.replace('/','')) for i in x]
        return [str.lower(i.replace('(','')) for i in x]
        return [str.lower(i.replace(')','')) for i in x]
        return [str.lower(i.replace("'",'')) for i in x]
        return [str.lower(i.replace("\\",'')) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace('/', ''))
            return str.lower(x.replace('(', ''))
            return str.lower(x.replace(')', ''))
            return str.lower(x.replace("'", ''))
            return str.lower(x.replace('\\', ''))
        else:
            return ''

# %%
books["soup"] = books["soup"].apply(sanitize)

books.head(3)
# Out:
#         book_id                    book_title        author publication_date  \
# 14646  24940694                         Anima
# 9585   10613695  Knitting Under the Influence
# 2114    1121236                      Crabwalk  Günter Grass             2002
#
#            genre                                            summary            \
# 14646  [Mystery]   Megan hopes to be an actress, and goes to Lon...  24940694
# 9585          []   Sometimes it feels like their weekly knitting...  10613695
# 2114     [Novel]   The narrator of the novella is the journalist...   1121236
#
#                                                     soup
# 14646  anima mystery   megan hopes to be an actress, ...
# 9585   knitting under the influence   sometimes it fe...
# 2114   crabwalk novel   the narrator of the novella i...

# %%
stop_words= stopwords.words('english') + list(string.punctuation)
# += list(['fire', 'emblem', 'game','awakening', 'conquest', 'fate', 'birthright', 'revelations', 'echo', 'shadow', 'valentia' ,'three', 'house', 'engage', 'play', 'buy', 'rpg'])
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  '!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
def lemmatization(texts,allowed_postags=['NOUN','ADJ','VERB','ADV']):
    """https://spacy.io/api/annotation"""
    data_words=simple_preprocess(str(texts))
    doc=nlp(' '.join(data_words))
    tokens = [token.lemma_ for token in doc if token.pos_ in allowed_postags]
    tokens = [word for word in tokens if word not in stop_words]
    # tokens = [word for word in tokens if word not in positive_words]
    # tokens = [word for word in tokens if word not in negative_words]

    return tokens

# %%
def soup_after_lemma(x):
    soups = ""
    for text in x['soup']:
        soups += text + " "
    return soups

# %%
books['soup'] = books['soup'].apply(lemmatization)

# %%
books["soup"] = books.apply(soup_after_lemma, axis=1)

# %%
books
# Out:
#         book_id                    book_title             author  \
# 14646  24940694                         Anima
# 9585   10613695  Knitting Under the Influence
# 2114    1121236                      Crabwalk       Günter Grass
# 5139    3983954            .hack//AI buster 2
# 12200  17370186                     Sasquatch       Roland Smith
# ...         ...                           ...                ...
# 13115  19998458          The Unforgiving Wind        John Harris
# 11715  16036731                   Star Bridge    Jack Williamson
# 11733  16081895  Lilith: A Snake in the Grass    Jack L. Chalker
# 7000    5913404                    Skybreaker      Kenneth Oppel
# 8003    7489971           From Potter's Field  Patricia Cornwell
#
#       publication_date                                              genre  \
# 14646                                                           [Mystery]
# 9585                                                                   []
# 2114              2002                                            [Novel]
# 5139                                                    [Science Fiction]
# 12200                                                           [Fantasy]
# ...                ...                                                ...
# 13115       1963-01-01                                  [Adventure novel]
# 11715             1955                                  [Science Fiction]
# 11733             1981             [Science Fiction, Speculative fiction]
# 7000        2005-07-20  [Speculative fiction, Fantasy, Steampunk, Adve...
# 8003              1995                                    [Crime Fiction]
#
#                                                  summary            \
# 14646   Megan hopes to be an actress, and goes to Lon...  24940694
# 9585    Sometimes it feels like their weekly knitting...  10613695
# 2114    The narrator of the novella is the journalist...   1121236
# 5139    Haruka Mizuhara, whose name was misspelled in...   3983954
# 12200   When Dylan accompanies his father to a meetin...  17370186
# ...                                                  ...       ...
# 13115   An expedition is planned by Commander Adams a...  19998458
# 11715   The scattered planets are held together by th...  16036731
# 11733   The Confederacy, a massive space empire, dupl...  16081895
# 7000    Matt Cruse has been stationed on the Flotsam,...   5913404
# 8003    The story begins as a rotten Christmas for Sc...   7489971
#
#                                                     soup
# 14646  anima mystery megan hope actress go audition t...
# 9585   knit influence sometimes feel weekly knitting ...
# 2114   crabwalk novel narrator novella journalist bea...
# 5139   hackai buster science name misspell translatio...
# 12200  sasquatch fantasy accompany father meeting big...
# ...                                                  ...
# 13115  unforgiving wind adventure novel expedition pl...
# 11715  science fiction scatter planet hold together e...
# 11733  grass science fiction speculative fiction conf...
# 7000   skybreaker speculative fiction fantasy steampu...
# 8003   potter field crime fiction story begin rotten ...
#
# [5000 rows x 8 columns]

# %% [markdown]
# ---
# ### Taylor Swift Songs Dataset

# %%
ts_1 = pd.read_csv("01-taylor_swift.csv")
ts_2 = pd.read_csv("02-fearless_taylors_version.csv")
ts_3 = pd.read_csv("03-speak_now_deluxe_package.csv")
ts_4 = pd.read_csv("04-red_deluxe_edition.csv")
ts_5 = pd.read_csv("05-1989_deluxe.csv")
ts_6 = pd.read_csv("06-reputation.csv")
ts_7 = pd.read_csv("07-lover.csv")
ts_8 = pd.read_csv("08-folklore_deluxe_version.csv")
ts_9 = pd.read_csv("09-evermore_deluxe_version.csv")

lyrics = pd.concat([ts_1, ts_2, ts_3, ts_4, ts_5, ts_6, ts_7, ts_8, ts_9])
lyrics.reset_index(drop=True, inplace=True)

# %%
lyrics.sample(5)
# Out:
#                        album_name                 track_title  track_n  \
# 7936    evermore (deluxe version)                        ​ivy       10
# 660   Fearless (Taylor’s Version)  Fifteen (Taylor’s Version)        2
# 5433                   reputation            King of My Heart       10
# 7146    folklore (deluxe version)            ​illicit affairs       10
# 2366           Speak Now (Deluxe)                    Innocent       11
#
#                                                  lyric  line
# 7936                       And drink my husband's wine    41
# 660   This is life before you know who you're gonna be    13
# 5433      'Cause all the boys and their expensive cars     8
# 7146                            A million little times    26
# 2366                    And everybody believed in you?     8

# %%
lyrics = lyrics.drop(columns=['line'])

lyrics = lyrics.groupby('track_title').agg({
    'album_name': 'first',  # You can use 'first' to retain the first occurrence of the author
    'track_n': 'first',
     'lyric': ' '.join
}).reset_index()

lyrics.drop_duplicates(subset=['lyric'])

lyrics['lyric']
# Out:
# 0      Knew he was a killer first time that I saw him...
# 1      It feels like a perfect night To dress up like...
# 2      Why would you wanna break a perfectly good hea...
# 3      I don't know what I want, so don't ask me 'Cau...
# 4      I blew things out of proportion, now you're bl...
#                              ...
# 158    Friends break up, friends get married Stranger...
# 159    Is it romantic how all my elegies eulogize me?...
# 160    Rebekah rode up on the afternoon train, it was...
# 161    I sit and watch you reading with your head low...
# 162    If I wanted to know who you were hanging with ...
# Name: lyric, Length: 163, dtype: object

# %%
def lyrics_soup(x):
    return x['album_name'] + " " + x['track_title']  + " " + x['lyric']

# %%
lyrics["soup"] = lyrics.apply(lyrics_soup, axis=1)
lyrics["soup"] = lyrics["soup"].apply(sanitize)
lyrics.sample()
# Out:
#        track_title                 album_name  track_n  \
# 141  ​coney island  evermore (deluxe version)        9
#
#                                                  lyric  \
# 141  Break my soul in two looking for you But you'r...
#
#                                                   soup
# 141  evermore (deluxe version) ​coney island break ...

# %%
lyrics['soup'] = lyrics['soup'].apply(lemmatization)

# %%
lyrics["soup"] = lyrics.apply(soup_after_lemma, axis=1)

# %%
lyrics.head()
# Out:
#               track_title            album_name  track_n  \
# 0        ...Ready for It?            reputation        1
# 1                      22  Red (Deluxe Edition)        6
# 2  A Perfectly Good Heart          Taylor Swift       14
# 3   A Place In This World          Taylor Swift        4
# 4               Afterglow                 Lover       15
#
#                                                lyric  \
# 0  Knew he was a killer first time that I saw him...
# 1  It feels like a perfect night To dress up like...
# 2  Why would you wanna break a perfectly good hea...
# 3  I don't know what I want, so don't ask me 'Cau...
# 4  I blew things out of proportion, now you're bl...
#
#                                                 soup
# 0  reputation ready know first time see wonder ma...
# 1  red deluxe edition feel perfect night dress hi...
# 2  swift perfectly good heart wanna break perfect...
# 3  swift place world know want ask still try figu...
# 4  blow thing proportion blue put jail pin hand b...

# %% [markdown]
# ---
# ### Creating Similarity Matrices

# %%
books_lyrics_soups = pd.concat([books['soup'], lyrics['soup']],ignore_index=True)

# %%
books_lyrics_count = CountVectorizer(stop_words = "english")
books_lyrics_count.fit(books_lyrics_soups)

books_to_lyrics_matrix = books_lyrics_count.transform(books['soup'])
lyrics_to_books_matrix = books_lyrics_count.transform(lyrics['soup'])

print(books_to_lyrics_matrix.shape, lyrics_to_books_matrix.shape)
# Out:
# (5000, 43876) (163, 43876)

# %%
cosine_sim_books_lyrics = cosine_similarity(books_to_lyrics_matrix, lyrics_to_books_matrix)
cosine_sim_books_lyrics
# Out:
# array([[0.04635508, 0.02847816, 0.00813459, ..., 0.11995427, 0.06236211,
#         0.04303619],
#        [0.09388312, 0.09155068, 0.04314887, ..., 0.02239114, 0.04811513,
#         0.0674463 ],
#        [0.03940182, 0.0316424 , 0.00542306, ..., 0.07352036, 0.04157474,
#         0.05379524],
#        ...,
#        [0.00191942, 0.0104817 , 0.03817382, ..., 0.00320447, 0.06197324,
#         0.02375991],
#        [0.08311239, 0.04713226, 0.01795068, ..., 0.05123307, 0.07568827,
#         0.0534197 ],
#        [0.05573051, 0.00507229, 0.        , ..., 0.01240562, 0.01332889,
#         0.01724679]])

# %%
cosine_sim_lyrics_books = cosine_similarity(lyrics_to_books_matrix, books_to_lyrics_matrix)
cosine_sim_lyrics_books
# Out:
# array([[0.04635508, 0.09388312, 0.03940182, ..., 0.00191942, 0.08311239,
#         0.05573051],
#        [0.02847816, 0.09155068, 0.0316424 , ..., 0.0104817 , 0.04713226,
#         0.00507229],
#        [0.00813459, 0.04314887, 0.00542306, ..., 0.03817382, 0.01795068,
#         0.        ],
#        ...,
#        [0.11995427, 0.02239114, 0.07352036, ..., 0.00320447, 0.05123307,
#         0.01240562],
#        [0.06236211, 0.04811513, 0.04157474, ..., 0.06197324, 0.07568827,
#         0.01332889],
#        [0.04303619, 0.0674463 , 0.05379524, ..., 0.02375991, 0.0534197 ,
#         0.01724679]])

# %%
books = books.reset_index()
books_indices = pd.Series(books.index, index=books['book_title'].apply(lambda x: x.lower() if x is not np.nan else "")).drop_duplicates()

books.head()
# Out:
#    index   book_id                    book_title        author  \
# 0  14646  24940694                         Anima
# 1   9585  10613695  Knitting Under the Influence
# 2   2114   1121236                      Crabwalk  Günter Grass
# 3   5139   3983954            .hack//AI buster 2
# 4  12200  17370186                     Sasquatch  Roland Smith
#
#   publication_date              genre  \
# 0                           [Mystery]
# 1                                  []
# 2             2002            [Novel]
# 3                   [Science Fiction]
# 4                           [Fantasy]
#
#                                              summary            \
# 0   Megan hopes to be an actress, and goes to Lon...  24940694
# 1   Sometimes it feels like their weekly knitting...  10613695
# 2   The narrator of the novella is the journalist...   1121236
# 3   Haruka Mizuhara, whose name was misspelled in...   3983954
# 4   When Dylan accompanies his father to a meetin...  17370186
#
#                                                 soup
# 0  anima mystery megan hope actress go audition t...
# 1  knit influence sometimes feel weekly knitting ...
# 2  crabwalk novel narrator novella journalist bea...
# 3  hackai buster science name misspell translatio...
# 4  sasquatch fantasy accompany father meeting big...

# %%
lyrics = lyrics.reset_index()
lyrics_indices = pd.Series(lyrics.index, index=lyrics['track_title'].apply(lambda x: x.lower() if x is not np.nan else "")).drop_duplicates()

lyrics.head()
# Out:
#    level_0  index             track_title            album_name  track_n  \
# 0        0      0        ...Ready for It?            reputation        1
# 1        1      1                      22  Red (Deluxe Edition)        6
# 2        2      2  A Perfectly Good Heart          Taylor Swift       14
# 3        3      3   A Place In This World          Taylor Swift        4
# 4        4      4               Afterglow                 Lover       15
#
#                                                lyric  \
# 0  Knew he was a killer first time that I saw him...
# 1  It feels like a perfect night To dress up like...
# 2  Why would you wanna break a perfectly good hea...
# 3  I don't know what I want, so don't ask me 'Cau...
# 4  I blew things out of proportion, now you're bl...
#
#                                                 soup
# 0  reputation ready know first time see wonder ma...
# 1  red deluxe edition feel perfect night dress hi...
# 2  swift perfectly good heart wanna break perfect...
# 3  swift place world know want ask still try figu...
# 4  blow thing proportion blue put jail pin hand b...

# %%
class RecommendationEngine:
    def get_books_from_lyrics(title):
        try:
            idx = lyrics_indices[title.lower()]
            sim_scores = list(enumerate(cosine_sim_lyrics_books[idx]))
            sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)

            sim_scores = sim_scores[:5]

            book_indices = [i[0] for i in sim_scores]

            return books.iloc[book_indices]
        except :
            print("No song found in our database. Please try again.")

    def get_lyrics_from_books(title):
        try:
            idx = books_indices[title.lower()]
            sim_scores = list(enumerate(cosine_sim_books_lyrics[idx]))
            sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)

            sim_scores = sim_scores[:5]

            lyrics_indices = [i[0] for i in sim_scores]

            return lyrics.iloc[lyrics_indices]
        except :
            print("No book found in our database. Please try again.")

# %%
rand = books["book_title"].sample(1).values[0]
rand
# Out:
# 'The Great Eight'

# %%
RecommendationEngine.get_lyrics_from_books(rand)
# Out:
#     level_0  index                        track_title  \
# 27       27     27                     Don’t Blame Me
# 61       61     61                          Long Live
# 57       57     57  Jump Then Fall (Taylor’s Version)
# 42       42     42     Hey Stephen (Taylor’s Version)
# 53       53     53                           Innocent
#
#                      album_name  track_n  \
# 27                   reputation        4
# 61           Speak Now (Deluxe)       14
# 57  Fearless (Taylor’s Version)       14
# 42  Fearless (Taylor’s Version)        4
# 53           Speak Now (Deluxe)       11
#
#                                                 lyric  \
# 27  Don't blame me, love made me crazy If it doesn...
# 61  I said, remember this moment, in the back of m...
# 57  I like the way you sound in the morning We're ...
# 42  Mmm-mm, mm-mm Mmm-mm, mm-mm Mmm-mm, mm-mm, yea...
# 53  I guess you really did it this time Left yours...
#
#                                                  soup
# 27  reputation blame blame love make crazy doin ri...
# 61  speak long live say remember moment back mind ...
# 57  version jump fall taylor version way sound mor...
# 42  version mmm mmm know look deceive know see lig...
# 53  speak deluxe innocent guess really time leave ...

# %%
# RecommendationEngine.get_lyrics_from_books('The Ramsay Scallop')
# Out:
# No book found in our database. Please try again.

# %%
rand = lyrics["track_title"].sample(1).values[0]
rand
# Out:
# 'I Knew You Were Trouble'

# %%
RecommendationEngine.get_books_from_lyrics(rand)
# Out:
#       index   book_id             book_title                   author  \
# 1034  11911  16614375      Ivan the Terrible                Anne Fine
# 3646  15290  27550660        Sugar and Spice  Lauren Katherine Conrad
# 175    5900   4844614        Henry and Ribsy           Beverly Cleary
# 2679  13528  21162721        The White Tiger
# 2882  16244  32570419  The Russian Concubine
#
#      publication_date                                    genre  \
# 1034       2007-06-04                  [Children's literature]
# 3646       2010-10-05                                       []
# 175                    [Children's literature, Fiction, Novel]
# 2679             1987                      [Thriller, Fiction]
# 2882             2007                     [Historical fiction]
#
#                                                 summary            \
# 1034   It is Ivan's first day of school. He can only...  16614375
# 3646   Lauren Conrad's second L.A. Candy book opens ...  27550660
# 175    Like most of the Henry Huggins books, the inc...   4844614
# 2679   Lu Hong, a policeman in Beijing finds himself...  21162721
# 2882   The story begins in 1917 when a five-year-old...  32570419
#
#                                                    soup
# 1034  terrible child literature first day school spe...
# 3646  candy book open red carpet premiere season red...
# 175   ribsy child literature fiction novel huggin bo...
# 2679  white tiger find trouble death strange circums...
# 2882  russian concubine historical fiction story beg...

# %%
RecommendationEngine.get_books_from_lyrics('Love Story (Taylor’s Version)')
# Out:
#       index   book_id                                      book_title  \
# 609    2015   1049941                                       Black Sun
# 2537  12944  19488801  Lulu Atlantis and the Quest for True Blue Love
# 4556   3168   2010476                                        Scarlett
# 1487   6923   5833227                                My Cousin Rachel
# 3604   4337   3133672                                   The Scapegoat
#
#                  author publication_date  \
# 609        Edward Abbey             1971
# 2537                          2008-01-08
# 4556   Alexandra Ripley          1991-09
# 1487  Daphne du Maurier             1951
# 3604  Daphne du Maurier             1957
#
#                                                   genre  \
# 609                   [Western, Fiction, Romance novel]
# 2537                                                 []
# 4556  [Travel, Novel, History, Historical fiction, R...
# 1487                    [Mystery, Novel, Romance novel]
# 3604                                    [Crime Fiction]
#
#                                                 summary            \
# 609    The book is divided into three parts: In the ...   1049941
# 2537   Lulu Lantis lives in Sweet Pea Lane. She has ...  19488801
# 4556   The book begins where Gone with the Wind left...   2010476
# 1487   The story of "My Cousin Rachel" begins with A...   5833227
# 3604   'I left the car by the side of the cathedral,...   3133672
#
#                                                    soup
# 609   black sun western fiction romance novel book d...
# 2537  quest true blue live sweet pea lane baby broth...
# 4556  travel novel history historical fiction romanc...
# 1487  cousin mystery novel romance novel story cousi...
# 3604  crime fiction leave car side cathedral walk st...

# %%
books.sample(5)['book_title']
# Out:
# 5607                               Pamela
# 10124               The House at Riverton
# 16398          Debt: The First 5000 Years
# 3245     The Mystery of the Aztec Warrior
# 6370               Murder Being Once Done
# Name: book_title, dtype: object

# %%
lyrics.sample(5)['track_title']
# Out:
# 124    You All Over Me (Taylor’s Version) [From the V...
# 34                           Fearless (Taylor’s Version)
# 99       That’s When (Taylor’s Version) [From the Vault]
# 56                         I’m Only Me When I’m with You
# 22                           Dancing with Our Hands Tied
# Name: track_title, dtype: object
